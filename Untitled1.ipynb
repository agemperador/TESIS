# %%
from WRF import *
# Out:
# /home/agustin/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/agustin/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
# !ls /media/agustin/1D36257C5C6244CB/WRF_sim/tracked_files/
# Out:
# System1_3D-wrfout_traj_B61-R30.nc   System3_3D-wrfout_traj_B61-R30.nc
# System1_qc_traj_B61-R30.nc	    System3_qc_traj_B61-R30.nc
# System1_qi_traj_B61-R30.nc	    System3_qi_traj_B61-R30.nc
# System1_qr_traj_B61-R30.nc	    System3_qr_traj_B61-R30.nc
# System1_qs_traj_B61-R30.nc	    System3_qs_traj_B61-R30.nc
# System1_qv_traj_B61-R30.nc	    System3_qv_traj_B61-R30.nc
# System1_SFC-wrfout_traj_B61-R30.nc  System3_SFC-wrfout_traj_B61-R30.nc
# System2_3D-wrfout_traj_B61-R30.nc   System4_3D-wrfout_traj_B61-R30.nc
# System2_qc_traj_B61-R30.nc	    System4_qc_traj_B61-R30.nc
# System2_qi_traj_B61-R30.nc	    System4_qi_traj_B61-R30.nc
# System2_qr_traj_B61-R30.nc	    System4_qr_traj_B61-R30.nc
# System2_qs_traj_B61-R30.nc	    System4_qs_traj_B61-R30.nc
# System2_qv_traj_B61-R30.nc	    System4_qv_traj_B61-R30.nc
# System2_SFC-wrfout_traj_B61-R30.nc  System4_SFC-wrfout_traj_B61-R30.nc

# %%
Dataset('/media/agustin/1D36257C5C6244CB/WRF_sim/tracked_files/System1_qc_traj_B61-R30.nc','r').variables
# Out:
# OrderedDict([('file', <class 'netCDF4._netCDF4.Variable'>
#               |S1 file(file, StrLength)
#                   standard_name: file
#                   long_name: Files found
#                   units: -
#                   file_criteria: /home/lluis.fita/salidas/estudios/RLPG181110/runs_FF/v361_control_ndg2//wrfwbqc*2018*00
#               unlimited dimensions:
#               current shape = (7, 500)
#               filling on, default _FillValue of  used),
#              ('nfile', <class 'netCDF4._netCDF4.Variable'>
#               int32 nfile(time)
#                   standard_name: nfile
#                   long_name: file with data at correspondant time-step of the trajectory
#                   units: 1
#               unlimited dimensions: time
#               current shape = (29,)
#               filling on, default _FillValue of -2147483647 used),
#              ('tstepfile', <class 'netCDF4._netCDF4.Variable'>
#               int32 tstepfile(time)
# ...
